# %% [markdown]
# # Data Toolkit Assignment

# %% [markdown]
# ## 1. What is NumPy, and why is it widely used in Python?

# %%
"""
NumPy is a Python library used for numerical computing.
It is widely used because it provides fast array operations,
mathematical functions, and supports multidimensional arrays.
"""

# %% [markdown]
# ## 2. How does broadcasting work in NumPy?

# %%
import numpy as np

a = np.array([1, 2, 3])
b = 5

print(a + b)

# %% [markdown]
# ## 3. What is a Pandas DataFrame?

# %%
"""
A Pandas DataFrame is a 2-dimensional table-like data structure
with rows and columns.
"""

# %% [markdown]
# ## 4. Explain the use of the groupby() method in Pandas

# %%
import pandas as pd

data = {
    "Department": ["IT", "HR", "IT", "HR"],
    "Salary": [50000, 40000, 60000, 45000]
}

df = pd.DataFrame(data)

print(df.groupby("Department").mean())

# %% [markdown]
# ## 5. Why is Seaborn preferred for statistical visualizations?

# %%
"""
Seaborn provides attractive statistical graphs with less code.
"""

# %% [markdown]
# ## 6. Differences between NumPy arrays and Python lists

# %%
"""
NumPy arrays are faster and memory efficient.
Python lists are flexible and can store mixed data types.
"""

# %% [markdown]
# ## 7. What is a heatmap, and when should it be used?

# %%
"""
A heatmap is a colored graphical representation of data.
It is commonly used for correlation analysis.
"""

# %% [markdown]
# ## 8. What does the term vectorized operation mean in NumPy?

# %%
import numpy as np

a = np.array([1, 2, 3])

print(a * 2)

# %% [markdown]
# ## 9. How does Matplotlib differ from Plotly?

# %%
"""
Matplotlib creates static plots.
Plotly creates interactive plots.
"""

# %% [markdown]
# ## 10. What is the significance of hierarchical indexing in Pandas?

# %%
"""
Hierarchical indexing allows multiple levels of indexing in Pandas.
"""

# %% [markdown]
# ## 11. What is the role of Seaborn pairplot() function?

# %%
"""
pairplot() is used to visualize relationships among variables.
"""

# %% [markdown]
# ## 12. What is the purpose of the describe() function in Pandas?

# %%
import pandas as pd

data = {"Marks": [50, 60, 70, 80]}

df = pd.DataFrame(data)

print(df.describe())

# %% [markdown]
# ## 13. Why is handling missing data important in Pandas?

# %%
"""
Handling missing data prevents incorrect analysis and improves accuracy.
"""

# %% [markdown]
# ## 14. What are the benefits of using Plotly for data visualization?

# %%
"""
Plotly provides interactive and visually appealing charts.
"""

# %% [markdown]
# ## 15. How does NumPy handle multidimensional arrays?

# %%
import numpy as np

arr = np.array([[1, 2], [3, 4]])

print(arr)

# %% [markdown]
# ## 16. What is the role of Bokeh in data visualization?

# %%
"""
Bokeh is used for creating interactive web visualizations.
"""

# %% [markdown]
# ## 17. Explain the difference between apply() and map() in Pandas

# %%
"""
map() works on Series only.
apply() works on both Series and DataFrames.
"""

# %% [markdown]
# ## 18. What are some advanced features of NumPy?

# %%
"""
1. Broadcasting
2. Vectorization
3. Linear Algebra
4. Random Number Generation
"""

# %% [markdown]
# ## 19. How does Pandas simplify time series analysis?

# %%
"""
Pandas provides date-time indexing and resampling tools.
"""

# %% [markdown]
# ## 20. What is the role of a pivot table in Pandas?

# %%
"""
Pivot tables summarize and organize data efficiently.
"""

# %% [markdown]
# ## 21. Why is NumPy’s array slicing faster than Python’s list slicing?

# %%
"""
NumPy arrays use contiguous memory allocation making slicing faster.
"""

# %% [markdown]
# ## 22. What are some common use cases for Seaborn?

# %%
"""
1. Heatmaps
2. Histograms
3. Pairplots
4. Statistical charts
"""

# %% [markdown]
# # Practical

# %% [markdown]
# ## 1. Create a 2D NumPy array and calculate the sum of each row

# %%
import numpy as np

arr = np.array([[1, 2, 3],
                [4, 5, 6]])

print(arr.sum(axis=1))

# %% [markdown]
# ## 2. Write a Pandas script to find the mean of a specific column in a DataFrame

# %%
import pandas as pd

df = pd.DataFrame({
    "Marks": [80, 90, 70, 60]
})

print(df["Marks"].mean())

# %% [markdown]
# ## 3. Create a scatter plot using Matplotlib

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.scatter(x, y)

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Scatter Plot")

plt.show()

# %% [markdown]
# ## 4. How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    "A": [1, 2, 3, 4],
    "B": [2, 4, 6, 8],
    "C": [5, 3, 6, 9]
}

df = pd.DataFrame(data)

corr = df.corr()

sns.heatmap(corr, annot=True)

plt.show()

# %% [markdown]
# ## 5. Generate a bar plot using Plotly

# %%
import plotly.express as px
import pandas as pd

df = pd.DataFrame({
    
    "Fruits": ["Apple", "Banana", "Orange"],
    "Count": [10, 15, 7]
})

fig = px.bar(df, x="Fruits", y="Count")

fig.show()

# %% [markdown]
# ## 6. Create a DataFrame and add a new column based on an existing column

# %%
import pandas as pd

df = pd.DataFrame({
    "Marks": [50, 60, 70]
})

df["Double_Marks"] = df["Marks"] * 2

print(df)

# %% [markdown]
# ## 7. Write a program to perform element-wise multiplication of two NumPy arrays

# %%
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

print(a * b)

# %% [markdown]
# ## 8. Create a line plot with multiple lines using Matplotlib

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]

y1 = [1, 4, 9, 16]
y2 = [2, 5, 8, 11]

plt.plot(x, y1, label="Line 1")
plt.plot(x, y2, label="Line 2")

plt.legend()

plt.show()

# %% [markdown]
# ## 9. Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold

# %%
import pandas as pd

df = pd.DataFrame({
    "Marks": [40, 75, 90, 55]
})

filtered = df[df["Marks"] > 60]

print(filtered)

# %% [markdown]
# ## 10. Create a histogram using Seaborn to visualize a distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = [10, 20, 20, 30, 40, 40, 40]

sns.histplot(data)

plt.show()

# %% [markdown]
# ## 11. Perform matrix multiplication using NumPy

# %%
import numpy as np

a = np.array([[1, 2],
              [3, 4]])

b = np.array([[5, 6],
              [7, 8]])

print(np.matmul(a, b))

# %% [markdown]
# ## 12. Use Pandas to load a CSV file and display its first 5 rows

# %%
import pandas as pd

df = pd.read_csv("data.csv")

print(df.head())

# %% [markdown]
# ## 13. Create a 3D scatter plot using Plotly

# %%
import plotly.express as px
import pandas as pd

df = pd.DataFrame({
    "x": [1, 2, 3],
    "y": [4, 5, 6],
    "z": [7, 8, 9]
})

fig = px.scatter_3d(df, x='x', y='y', z='z')

fig.show()
